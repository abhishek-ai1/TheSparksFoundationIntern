# %% [markdown]
# ***The Sparks Foundation***
#
# **Data Science and Business Intelligence Internship**
#
# **Task-3 Exploratory Data Analysis on SampleSuperstore**
#
# *As a business manager, try to find out the weak areas where you can work to make more profit.*
#
# What all business problems you can derive by exploring the data?
#
# *Importing Packages*

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the file

# %%
dataset=pd.read_csv("C:/Users/Abhishek/Downloads/SampleSuperstore.csv")

# %% [markdown]
# Displaying First 10 values in the dataset

# %%
dataset.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# 5        90032   West        Furniture  Furnishings   48.8600         7
# 6        90032   West  Office Supplies          Art    7.2800         4
# 7        90032   West       Technology       Phones  907.1520         6
# 8        90032   West  Office Supplies      Binders   18.5040         3
# 9        90032   West  Office Supplies   Appliances  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700

# %% [markdown]
# Displaying any random 5 rows in the dataset

# %%
dataset.sample(5)
# Out:
#            Ship Mode      Segment        Country         City       State  \
# 6465  Standard Class     Consumer  United States      Lebanon   Tennessee
# 4859  Standard Class    Corporate  United States     Oak Park    Illinois
# 2525  Standard Class     Consumer  United States      Houston       Texas
# 3557  Standard Class     Consumer  United States  Los Angeles  California
# 7328  Standard Class  Home Office  United States      Burbank  California
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 6465        37087    South  Office Supplies      Storage    84.960         6
# 4859        60302  Central  Office Supplies          Art    10.192         7
# 2525        77041  Central       Technology  Accessories    25.488         2
# 3557        90008     West  Office Supplies      Binders    10.128         2
# 7328        91505     West       Technology     Machines  1279.968         4
#
#       Discount    Profit
# 6465       0.2    6.3720
# 4859       0.2    1.0192
# 2525       0.2    4.4604
# 3557       0.2    3.6714
# 7328       0.2  415.9896

# %% [markdown]
# Determining Missing values if any

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Datatypes of the columns

# %%
dataset.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# Shape of the dataset

# %%
dataset.shape
# Out:
# (9994, 13)

# %% [markdown]
# Information about the dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# Statistical Description about the dataset

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Determine Duplicates if any

# %%
dataset.duplicated().sum()
# Out:
# 17

# %% [markdown]
# Removing Duplicates

# %%
dataset.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %% [markdown]
# To Display Distinct values within a column

# %%
dataset.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# Univariate Analysis
#
# Analyzing the segment of people in the store

# %%
Number_segment=dataset['Segment'].value_counts()
print(Number_segment)
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
Percentage_segment=Number_segment/len(dataset['Segment'])*100
print(Percentage_segment)
# Out:
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: Segment, dtype: float64

# %%
Percentage_segment.plot(kind='bar')
print("Percentage of each Segment")
# Out:
# Percentage of each Segment

# %% [markdown]
# Conclusion
#
#
# More than 50% of the people in the Store are Consumers
#
# Around 30% of the people in the Store are in the Corporate Segment
#
# Around 20% of the people in the Store belong to Home Office

# %% [markdown]
# Analyzing the Ship Mode in the store

# %%
Number_Shipmode=dataset['Ship Mode'].value_counts()
print(Number_Shipmode)
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
Percentage_Shipmode=Number_Shipmode/len(dataset['Ship Mode'])*100
print(Percentage_Shipmode)
# Out:
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: Ship Mode, dtype: float64

# %%
Percentage_Shipmode.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conclusion
#
#
# Most common mode of Delivery is Standard Class(~60%)
#
# Very less number of Deliveries reach the same day(~5%)

# %% [markdown]
# Conclusion
#
#
# Most common mode of Delivery is Standard Class(~60%)
#
# Very less number of Deliveries reach the same day(~5%)
#
# Analyzing the region of orders

# %%
Number_Region=dataset['Region'].value_counts()
print(Number_Region)
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
Percentage_Region=Number_Region/len(dataset['Region'])*100
print(Percentage_Region)
# Out:
# West       32.049230
# East       28.497098
# Central    23.243946
# South      16.209726
# Name: Region, dtype: float64

# %%
Percentage_Region.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conclusion
#
# *Most orders are from west And least orders are from South*

# %% [markdown]
# Analyzing Categories of orders

# %%
Number_Categories=dataset['Category'].value_counts()
print(Number_Categories)
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
Percentage_Category=Number_Categories/len(dataset['Category'])*100
print(Percentage_Category)
# Out:
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: Category, dtype: float64

# %%
Percentage_Category.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# Conclusion:
#
#
# 60% orders are of categories - office supplies
#
# The remaining 40 % are of Furniture and Technology(~20% each catogory)

# %% [markdown]
# Plotting Subcategories

# %%
dataset['Sub-Category'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conclusion
#
#
# *Binders and Papers are bought most frequently*
#
# *Machines and Copiers are bought least frequently*

# %% [markdown]
# Counting number of orders from each state

# %%
print(dataset['State'].value_counts())
plt.figure(figsize=(15,8))
sns.countplot(x=dataset['State'])
plt.xticks(rotation=90)
plt.show()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# Louisiana                 42
# South Carolina            42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %% [markdown]
# Conclusion
#
# Most of the orders are in California, followed by New York.

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Finding the correlation of dataset

# %%
col=['Postal Code']
data_1=dataset.drop(columns=col,axis=1)
data_1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# Conclusion
#
# As Sales increases the Profit obtained increaes, and the discount offered deceases.

# %% [markdown]
# Heat map of Correlation Matrix

# %%
col=['Postal Code']
data_1=dataset.drop(columns=col,axis=1)
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(data_1.corr(), annot= True)
plt.show()

# %% [markdown]
# Conclusion
#
# Sales and Profit are positively correlated.
#
#   As a general trend we can say as the Sales increases Profit Increases.
#
# Discount and Profit are negatively correlated.
#
#   As a general trend we can say as the Discount decreases Profit Increases

# %% [markdown]
# Analyzing Sales and Profit per Segment

# %%
fig, ax = plt.subplots()
colors={'Consumer':'red','Corporate':'green','Home Office':'yellow'}
ax.scatter(dataset['Sales'],dataset['Profit'],c=dataset['Segment'].apply(lambda x: colors[x]))
plt.show()

# %%
x=data_1.groupby(dataset['Segment']).agg('sum')
print(x)

x['Sales'].plot(kind='bar')
# Out:
#                     Sales  Quantity  Discount       Profit
# Segment
# Consumer     1.161401e+06     19521    820.91  134119.2092
# Corporate    7.061464e+05     11608    477.85   91979.1340
# Home Office  4.296531e+05      6744    262.33   60298.6785
# <AxesSubplot:xlabel='Segment'>

# %%
x['Profit'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Segment'>

# %%
x=dataset.groupby(dataset['Segment']).agg(['min','max','median','sum'])
print(x['Sales'])
# Out:
#                min       max  median           sum
# Segment
# Consumer     0.444  13999.96   53.72  1.161401e+06
# Corporate    0.556  17499.95   56.54  7.061464e+05
# Home Office  0.990  22638.48   52.44  4.296531e+05

# %%
x=dataset.groupby(dataset['Segment']).agg(['min','max','median','sum'])
print(x['Profit'])
# Out:
#                    min        max  median          sum
# Segment
# Consumer    -6599.9780  6719.9808  8.3754  134119.2092
# Corporate   -3839.9904  8399.9760  8.6940   91979.1340
# Home Office -3399.9800  3919.9888  9.1020   60298.6785

# %%
dataset.pivot_table(values='Sales',index='Segment',columns='Discount',aggfunc='median')
# Out:
# Discount       0.00     0.10     0.15    0.20     0.30      0.32     0.40  \
# Segment
# Consumer     51.900  365.598  307.666  51.540  361.011  328.3992  289.404
# Corporate    58.580  245.646  480.165  52.184  347.361  307.6660  338.679
# Home Office  49.645  191.646  411.332  52.680  362.901  341.9992  212.856
#
# Discount          0.45     0.50    0.60    0.70   0.80
# Segment
# Consumer     353.24025  292.100  23.526  12.051  8.568
# Corporate    562.29250  302.450  21.936  12.060  9.264
# Home Office  427.23725  433.935  22.608  12.957  8.769

# %%
dataset.pivot_table(values='Profit',index='Segment',columns='Discount',aggfunc='median')
# Out:
# Discount        0.00     0.10      0.15    0.20     0.30     0.32      0.40  \
# Segment
# Consumer     16.1240  62.0390   5.12940  6.0433 -26.0562 -30.0980 -47.21360
# Corporate    16.2688  46.7908  26.27735  6.7054 -28.2240 -59.0606 -87.27495
# Home Office  15.4546  37.2300  16.79860  7.2576 -18.2040 -57.3234 -49.71900
#
# Discount          0.45      0.50     0.60    0.70     0.80
# Segment
# Consumer    -135.68145 -175.2600 -14.1323 -8.7276 -13.7175
# Corporate   -255.58750 -120.5130 -10.4196 -8.9796 -16.3800
# Home Office -175.14690 -237.8425 -14.2290 -9.7608 -14.0328

# %% [markdown]
# Conclusion
#
# The consumer segment has the maximum Sales and Profit
#
# For a discount of 30% and more the orders where at loss

# %% [markdown]
# Analyzing Sales and Profit Regionwise

# %%
x=data_1.groupby(dataset['Region']).agg('sum')
print(x)

x['Sales'].plot(kind='bar')
# Out:
#                Sales  Quantity  Discount       Profit
# Region
# Central  501239.8908      8780    558.34   39706.3625
# East     678781.2400     10618    414.00   91522.7800
# South    391721.9050      6209    238.55   46749.4303
# West     725457.8245     12266    350.20  108418.4489
# <AxesSubplot:xlabel='Region'>

# %%
x['Profit'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
x=dataset.groupby(dataset['Region']).agg(['min','max','median','sum'])
print(x['Sales'])
# Out:
#            min        max  median          sum
# Region
# Central  0.444  17499.950  45.980  501239.8908
# East     0.852  11199.968  54.900  678781.2400
# South    1.167  22638.480  54.594  391721.9050
# West     0.990  13999.960  60.840  725457.8245

# %%
x=dataset.groupby(dataset['Region']).agg(['min','max','median','sum'])
print(x['Profit'])
# Out:
#                min        max   median          sum
# Region
# Central -3701.8928  8399.9760   5.1840   39706.3625
# East    -6599.9780  5039.9856   8.1717   91522.7800
# South   -3839.9904  3177.4750   9.0720   46749.4303
# West    -3399.9800  6719.9808  11.1664  108418.4489

# %%
dataset.pivot_table(values='Sales',index='Region',columns='Discount',aggfunc='median')
# Out:
# Discount    0.00     0.10     0.15    0.20     0.30      0.32     0.40  \
# Region
# Central   64.385  227.430      NaN  39.984  359.058  328.3992  559.710
# East      57.750  365.598      NaN  35.296  346.087       NaN  280.782
# South     67.960      NaN      NaN  47.952      NaN       NaN  576.894
# West      43.940      NaN  359.499  99.592      NaN       NaN      NaN
#
# Discount     0.45      0.50    0.60     0.70   0.80
# Region
# Central       NaN  280.5175  22.494      NaN  8.701
# East          NaN  300.7225     NaN  11.0880    NaN
# South     383.438  695.7000     NaN  12.4695    NaN
# West          NaN  371.2000     NaN  19.0380    NaN

# %%
dataset.pivot_table(values='Profit',index='Region',columns='Discount',aggfunc='median')
# Out:
# Discount      0.00     0.10    0.15    0.20     0.30     0.32      0.40  \
# Region
# Central   19.67860  51.1578     NaN  5.4432 -26.6352 -46.9764  -97.7200
# East      16.78860  56.8506     NaN  5.3690 -24.0862      NaN  -52.3365
# South     19.80720      NaN     NaN  5.4432      NaN      NaN -195.7772
# West      13.48425      NaN  14.098  9.8328      NaN      NaN       NaN
#
# Discount      0.45       0.50     0.60     0.70     0.80
# Region
# Central        NaN -180.04830 -12.0617      NaN -14.0498
# East           NaN -183.80150      NaN  -7.8450      NaN
# South    -167.3184  -69.66375      NaN  -9.4002      NaN
# West           NaN -196.57290      NaN -13.8924      NaN

# %% [markdown]
# Conclusion
#
# For upto 20% discount, the items are Sold at Profit.
#
# West Region has the maximum Sales followed by East, Central and South.
#
# However, in terms of profit obtained the order is Slightly different. West Region has the maximum Profit followed by East, South and Central.
#
# Maximum demands of goods are in West and East

# %% [markdown]
# Analyzing Sales and Profit on Category

# %%
x=data_1.groupby(dataset['State']).agg({'Sales':['sum'],'Profit':['sum'],'Quantity':['sum']})
x.style.background_gradient(cmap ='viridis')\
        .set_properties(**{'font-size': '15px'})
# Out:
# <style type="text/css">
# #T_fd001_row0_col0, #T_fd001_row21_col2, #T_fd001_row34_col0 {
#   background-color: #471063;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row0_col1 {
#   background-color: #33628d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row0_col2, #T_fd001_row23_col2, #T_fd001_row26_col0, #T_fd001_row34_col2 {
#   background-color: #470d60;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row1_col0, #T_fd001_row12_col2, #T_fd001_row15_col0, #T_fd001_row28_col0 {
#   background-color: #481c6e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row1_col1, #T_fd001_row8_col1 {
#   background-color: #3f4889;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row1_col2 {
#   background-color: #482878;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row2_col0, #T_fd001_row5_col0, #T_fd001_row37_col2 {
#   background-color: #460a5d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row2_col1 {
#   background-color: #365d8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row2_col2, #T_fd001_row22_col2, #T_fd001_row42_col2 {
#   background-color: #460b5e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row3_col0, #T_fd001_row3_col1, #T_fd001_row3_col2 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 15px;
# }
# #T_fd001_row4_col0, #T_fd001_row15_col2, #T_fd001_row47_col0 {
#   background-color: #481a6c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row4_col1 {
#   background-color: #424086;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row4_col2, #T_fd001_row9_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row5_col1 {
#   background-color: #365c8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row5_col2, #T_fd001_row35_col0 {
#   background-color: #470e61;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row6_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row6_col1, #T_fd001_row28_col1 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row6_col2, #T_fd001_row18_col0, #T_fd001_row37_col0 {
#   background-color: #471365;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row7_col0, #T_fd001_row7_col2, #T_fd001_row10_col0, #T_fd001_row14_col0, #T_fd001_row17_col2, #T_fd001_row24_col2, #T_fd001_row39_col2, #T_fd001_row43_col2 {
#   background-color: #440256;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row7_col1, #T_fd001_row13_col1, #T_fd001_row29_col1 {
#   background-color: #39558c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row8_col0 {
#   background-color: #424186;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row8_col2, #T_fd001_row31_col1 {
#   background-color: #433d84;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row9_col0 {
#   background-color: #482677;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row9_col1 {
#   background-color: #297b8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row10_col1, #T_fd001_row14_col1 {
#   background-color: #3a548c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row10_col2, #T_fd001_row13_col0, #T_fd001_row14_col2, #T_fd001_row24_col0, #T_fd001_row29_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row11_col0 {
#   background-color: #443b84;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row11_col1, #T_fd001_row31_col2 {
#   background-color: #472d7b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row11_col2, #T_fd001_row35_col1 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row12_col0, #T_fd001_row44_col2 {
#   background-color: #482979;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row12_col1 {
#   background-color: #27808e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row13_col2, #T_fd001_row25_col0, #T_fd001_row27_col0 {
#   background-color: #450559;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row15_col1 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row16_col0, #T_fd001_row25_col2, #T_fd001_row27_col2, #T_fd001_row29_col2, #T_fd001_row38_col0, #T_fd001_row43_col0 {
#   background-color: #46075a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row16_col1, #T_fd001_row42_col1, #T_fd001_row43_col1 {
#   background-color: #38598c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row16_col2, #T_fd001_row22_col0, #T_fd001_row26_col2, #T_fd001_row38_col2, #T_fd001_row42_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row17_col0, #T_fd001_row32_col0, #T_fd001_row32_col2, #T_fd001_row39_col0, #T_fd001_row41_col1, #T_fd001_row46_col0, #T_fd001_row46_col2, #T_fd001_row48_col0, #T_fd001_row48_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row17_col1, #T_fd001_row32_col1, #T_fd001_row39_col1 {
#   background-color: #3a538b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row18_col1, #T_fd001_row37_col1 {
#   background-color: #32658e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row18_col2 {
#   background-color: #481467;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row19_col0, #T_fd001_row28_col2, #T_fd001_row47_col2 {
#   background-color: #481769;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row19_col1 {
#   background-color: #32648e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row19_col2, #T_fd001_row21_col0, #T_fd001_row35_col2, #T_fd001_row40_col0 {
#   background-color: #48186a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row20_col0 {
#   background-color: #443983;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row20_col1 {
#   background-color: #218e8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row20_col2 {
#   background-color: #472c7a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row21_col1 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row22_col1, #T_fd001_row26_col1 {
#   background-color: #375b8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row23_col0 {
#   background-color: #471164;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row23_col1 {
#   background-color: #33638d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row24_col1, #T_fd001_row25_col1 {
#   background-color: #38588c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row27_col1, #T_fd001_row38_col1 {
#   background-color: #39568c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row30_col0 {
#   background-color: #3aba76;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row30_col1 {
#   background-color: #f1e51d;
#   color: #000000;
#   font-size: 15px;
# }
# #T_fd001_row30_col2 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row31_col0 {
#   background-color: #472a7a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row33_col0 {
#   background-color: #443a83;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row33_col1 {
#   background-color: #481f70;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row33_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row34_col1 {
#   background-color: #355f8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row36_col0, #T_fd001_row46_col1, #T_fd001_row48_col1 {
#   background-color: #3b528b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row36_col1 {
#   background-color: #482475;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row36_col2 {
#   background-color: #375a8c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row40_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row40_col2 {
#   background-color: #482071;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row41_col0 {
#   background-color: #2d718e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row41_col2 {
#   background-color: #228d8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row44_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row44_col1 {
#   background-color: #26818e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row45_col0 {
#   background-color: #34608d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row45_col1 {
#   background-color: #20a386;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_fd001_row45_col2 {
#   background-color: #3c508b;
#   color: #f

# %%
x['Profit'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='State'>

# %%
dataset.pivot_table(values='Profit',index='Category',columns='Discount',aggfunc='median')
# Out:
# Discount            0.00       0.10    0.15     0.20     0.30     0.32  \
# Category
# Furniture        26.0706   56.85060  14.098   6.3780 -27.4296 -46.9764
# Office Supplies  11.7208   47.56220     NaN   5.3340      NaN      NaN
# Technology       43.5981  416.04215     NaN  19.1786  43.1991      NaN
#
# Discount             0.40      0.45       0.50     0.60     0.70     0.80
# Category
# Furniture       -120.0508 -167.3184 -187.20840 -12.0617 -191.646      NaN
# Office Supplies       NaN       NaN        NaN      NaN   -7.731 -14.0498
# Technology       -26.9955       NaN  -69.66375      NaN -337.638      NaN

# %%
x=dataset.groupby(dataset['Category']).agg(['min','max','median','sum'])
print(x['Sales'])
# Out:
#                    min        max   median          sum
# Category
# Furniture        1.892   4416.174  182.220  741999.7953
# Office Supplies  0.444   9892.740   27.418  719047.0320
# Technology       0.990  22638.480  166.160  836154.0330

# %%
x=dataset.groupby(dataset['Category']).agg(['min','max','median','sum'])
print(x['Profit'])
# Out:
#                        min       max   median          sum
# Category
# Furniture       -1862.3124  1013.127   7.7748   18451.2728
# Office Supplies -3701.8928  4946.370   6.8824  122490.8008
# Technology      -6599.9780  8399.976  25.0182  145454.9481

# %% [markdown]
# Conclusion
#
# Maximum Sales have been obtained by Technological Supplies, Followed by Furniture and Office Supplies
#
# Maximum Profit has been obtained by Technological Supplies, Followed by Office Supplies and Furniture.
#
# A discount of more than 30% has not been profitable for Technological and Office Supplies.
#
# More than 20% discount has not been profitable for Furniture

# %% [markdown]
# Analyzing Profit for each mode of shipment

# %%
x=dataset.groupby(dataset['Ship Mode']).agg('sum')
print(x['Profit'])
x['Profit'].plot(kind='bar')
# Out:
# Ship Mode
# First Class        48969.8399
# Same Day           15891.7589
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64
# <AxesSubplot:xlabel='Ship Mode'>

# %%
x=data_1.groupby(dataset['Category']).agg('sum')
print(x)

x['Sales'].plot(kind='bar')
# Out:
#                        Sales  Quantity  Discount       Profit
# Category
# Furniture        741999.7953      8028    368.89   18451.2728
# Office Supplies  719047.0320     22906    947.80  122490.8008
# Technology       836154.0330      6939    244.40  145454.9481
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# Conclusion
#
# Maximum profit is obtained through sales where the mode of delivery was "Standard Class", followed by "second class", "first class" and "Same Day".

# %% [markdown]
# Analyzing Sales, Quantity and Profit for each Category in each Segment, Region-wise

# %%
Table=dataset.groupby(['Region','Segment','Category']).agg({'Sales':['sum'],'Profit':['sum'],'Quantity':['sum']})
Table.style.background_gradient(cmap ='viridis')\
        .set_properties(**{'font-size': '15px'})
# Out:
# <style type="text/css">
# #T_c26eb_row0_col0 {
#   background-color: #20a486;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row0_col1, #T_c26eb_row24_col0, #T_c26eb_row24_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row0_col2, #T_c26eb_row25_col1 {
#   background-color: #404688;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row1_col0 {
#   background-color: #2db27d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row1_col1, #T_c26eb_row4_col0 {
#   background-color: #404588;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row1_col2, #T_c26eb_row31_col1 {
#   background-color: #48c16e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row2_col0, #T_c26eb_row19_col2 {
#   background-color: #23898e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row2_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row2_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row3_col0 {
#   background-color: #355f8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row3_col1 {
#   background-color: #414287;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row3_col2 {
#   background-color: #482475;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row4_col1 {
#   background-color: #472d7b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row4_col2, #T_c26eb_row16_col1 {
#   background-color: #2b758e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row5_col0 {
#   background-color: #29798e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row5_col1 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row5_col2 {
#   background-color: #481c6e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row6_col0 {
#   background-color: #481b6d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row6_col1 {
#   background-color: #482071;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row6_col2 {
#   background-color: #471063;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row7_col0, #T_c26eb_row8_col0, #T_c26eb_row12_col1 {
#   background-color: #472f7d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row7_col1 {
#   background-color: #32658e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row7_col2 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row8_col1, #T_c26eb_row17_col0, #T_c26eb_row19_col0 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row8_col2 {
#   background-color: #470d60;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row9_col0 {
#   background-color: #89d548;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row9_col1 {
#   background-color: #424086;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row9_col2 {
#   background-color: #3a538b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row10_col0 {
#   background-color: #4ac16d;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row10_col1 {
#   background-color: #54c568;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row10_col2 {
#   background-color: #93d741;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row11_col0, #T_c26eb_row28_col2, #T_c26eb_row29_col1 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row11_col1 {
#   background-color: #5ec962;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row11_col2 {
#   background-color: #3e4989;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row12_col0, #T_c26eb_row34_col1 {
#   background-color: #2a788e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row12_col2, #T_c26eb_row15_col1, #T_c26eb_row32_col2 {
#   background-color: #46337f;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row13_col0 {
#   background-color: #287d8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row13_col1 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row13_col2, #T_c26eb_row31_col0 {
#   background-color: #20928c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row14_col0 {
#   background-color: #25838e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row14_col1 {
#   background-color: #26818e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row14_col2 {
#   background-color: #482979;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row15_col0, #T_c26eb_row20_col2 {
#   background-color: #482878;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row15_col2 {
#   background-color: #481467;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row16_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row16_col2, #T_c26eb_row33_col0 {
#   background-color: #38598c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row17_col1 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row17_col2 {
#   background-color: #471365;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row18_col0 {
#   background-color: #25858e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row18_col1, #T_c26eb_row35_col1 {
#   background-color: #38588c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row18_col2 {
#   background-color: #46307e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row19_col1 {
#   background-color: #287c8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row20_col0 {
#   background-color: #297a8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row20_col1 {
#   background-color: #1f998a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row21_col0 {
#   background-color: #482677;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row21_col1 {
#   background-color: #453581;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row21_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row22_col0 {
#   background-color: #3c508b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row22_col1 {
#   background-color: #2c738e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row22_col2 {
#   background-color: #34608d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row23_col0 {
#   background-color: #3b518b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row23_col1 {
#   background-color: #32648e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row23_col2 {
#   background-color: #470e61;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row24_col1 {
#   background-color: #453882;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row25_col0 {
#   background-color: #460b5e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row25_col2 {
#   background-color: #472a7a;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row26_col0 {
#   background-color: #443a83;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row26_col1 {
#   background-color: #463480;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row26_col2 {
#   background-color: #450457;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row27_col0 {
#   background-color: #a8db34;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row27_col1 {
#   background-color: #39558c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row27_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row28_col0 {
#   background-color: #73d056;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row28_col1 {
#   background-color: #cde11d;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row29_col0 {
#   background-color: #f1e51d;
#   color: #000000;
#   font-size: 15px;
# }
# #T_c26eb_row29_col2 {
#   background-color: #365c8d;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row30_col0 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row30_col1 {
#   background-color: #3b528b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row30_col2 {
#   background-color: #443b84;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row31_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row32_col0 {
#   background-color: #297b8e;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row32_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row33_col1 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row33_col2 {
#   background-color: #481d6f;
#   color: #f1f1f1;
#   font-size: 15px;
# }
# #T_c26eb_row34_col0 {
#   ba

# %% [markdown]
# Conclusion
#
# The furniture sold in the Consumer and Corporate Segment in the Central Region is in overall loss
#
# All the other transactions are in Profit.
#
# There is an extremely high demand of office supplies by the consumers in the West and East.

# %% [markdown]
# Lets Summarize
# We analyzed how sales and profit sold varies region-wise and segment-wise, category-wise.
#
# We analzed how profit varies with discount in each division.
#
# We analyzed how Sales, Profit and Quantity varied for each category in the each segment regionwise.
#
# We learn that
# Technological items are in demand. So if production in this field will be more, then company will attain greater profit.
#
# Profit gain is highest in Consumer segment. So the Company must emphasise more in the Consumer segment.
#
# There is an extremely high demand of office supplies by the consumers in the West and East.Company can increase product supply.
#
# West Region has the maximum Profit followed by East, South and Central.Adequate Marketing Strategies should be implemented to boost Sales.
#
# California and New York have the highest Profit and Demand. Product Supply must be ensured to further increase sales and profit.
